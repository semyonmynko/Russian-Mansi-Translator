# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.1 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from sacrebleu) (2024.5.15)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.10/site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from sacrebleu) (1.26.4)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from sacrebleu) (5.3.0)
# Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 5.1 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Installing collected packages: portalocker, sacrebleu
# Successfully installed portalocker-2.10.1 sacrebleu-2.4.3

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, Seq2SeqTrainer, Seq2SeqTrainingArguments
from datasets import Dataset
import sacrebleu

# %%
df = pd.read_csv("/kaggle/input/mansi-russian-parralel-corpus/overall_80K.csv")

# %%
df
# Out:
#        Unnamed: 0                                             target  \
# 0               0  Та пыгрисит маим вармаль э̄рнэ поратэт ат верм...
# 1               1  Ха̄йтыматэ тӯр ва̄тан ёхтыс, вит ва̄тан ха̄йтыс.
# 2               2                          Вит са̄мыл сунсым о̄нтыс
# 3               3        Атаявев, акваг лылынг тагл ворн та тотавев.
# 4               4  Ман ты пӣлтал,  веськат хумиюв  нэтхуньт ат ёр...
# ...           ...                                                ...
# 81141        2345  А̄нумн ка̄салахты аквтуп тамле о̄лнэ накыт ма̄...
# 81142        2346                  А̄танэ нё̄тнэ̄г юил акван-атманэ.
# 81143        2347        Тох тай, культура сака тэ̄пгалан мед а̄тим.
# 81144        2348  Тувыл Уэйтс ты музыкантыг ёт, Чарли Рич ос Фрэ...
# 81145        2349         Тох ман ро̄ви та̄ра юртанын воськасаӈквет?
#
#                                                   source
# 0      Те мальчики не выполнят задание в назначенный ...
# 1        Бегая к берегу озера пришла, к воде подбежала.
# 2                              Вода прибывала на глазах
# 3            Обнюхивает нас, живыми на кладбище уносит.
# 4         Мы никогда не забудем этого честного человека.
# ...                                                  ...
# 81141  Мне кажется, что подобные случаи могут вызыват...
# 81142                    Волосы аккуратно собраны сзади.
# 81143  В общем, культуры интенсивного потребления мед...
# 81144  Затем Уэйтс отправился на гастроли с такими му...
# 81145  Но разве можно вот так просто покинуть своих д...
#
# [81146 rows x 3 columns]

# %%
# чистим дф от мусора
df = df.drop(columns=[df.columns[0]])

# %%
df
# Out:
#                                                   target  \
# 0      Та пыгрисит маим вармаль э̄рнэ поратэт ат верм...
# 1      Ха̄йтыматэ тӯр ва̄тан ёхтыс, вит ва̄тан ха̄йтыс.
# 2                              Вит са̄мыл сунсым о̄нтыс
# 3            Атаявев, акваг лылынг тагл ворн та тотавев.
# 4      Ман ты пӣлтал,  веськат хумиюв  нэтхуньт ат ёр...
# ...                                                  ...
# 81141  А̄нумн ка̄салахты аквтуп тамле о̄лнэ накыт ма̄...
# 81142                  А̄танэ нё̄тнэ̄г юил акван-атманэ.
# 81143        Тох тай, культура сака тэ̄пгалан мед а̄тим.
# 81144  Тувыл Уэйтс ты музыкантыг ёт, Чарли Рич ос Фрэ...
# 81145         Тох ман ро̄ви та̄ра юртанын воськасаӈквет?
#
#                                                   source
# 0      Те мальчики не выполнят задание в назначенный ...
# 1        Бегая к берегу озера пришла, к воде подбежала.
# 2                              Вода прибывала на глазах
# 3            Обнюхивает нас, живыми на кладбище уносит.
# 4         Мы никогда не забудем этого честного человека.
# ...                                                  ...
# 81141  Мне кажется, что подобные случаи могут вызыват...
# 81142                    Волосы аккуратно собраны сзади.
# 81143  В общем, культуры интенсивного потребления мед...
# 81144  Затем Уэйтс отправился на гастроли с такими му...
# 81145  Но разве можно вот так просто покинуть своих д...
#
# [81146 rows x 2 columns]

# %%
train_df, test_val_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(test_val_df, test_size=0.5, random_state=42)

# %%
train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)
test_dataset = Dataset.from_pandas(test_df)

# %%
tokenizer = AutoTokenizer.from_pretrained("tartuNLP/m2m100_418M_smugri")
model = AutoModelForSeq2SeqLM.from_pretrained("tartuNLP/m2m100_418M_smugri")
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# config.json:   0%|          | 0.00/931 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.94G [00:00<?, ?B/s]

# %%
tokenizer.add_special_tokens({'additional_special_tokens': ['<mns_MNS>']})
model.resize_token_embeddings(len(tokenizer))
# Out:
# M2M100ScaledWordEmbedding(128109, 1024, padding_idx=1)

# %%
def preprocess_function(examples):
    inputs = tokenizer(examples['source'], truncation=True, padding='max_length', max_length=128)
    targets = tokenizer(examples['target'], truncation=True, padding='max_length', max_length=128)
    inputs['labels'] = targets['input_ids']
    return inputs

# %%
train_dataset = train_dataset.map(preprocess_function, batched=True)
val_dataset = val_dataset.map(preprocess_function, batched=True)
test_dataset = test_dataset.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/64916 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8115 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8115 [00:00<?, ? examples/s]

# %%
train_dataset = train_dataset.remove_columns(['source', 'target', '__index_level_0__'])
val_dataset = val_dataset.remove_columns(['source', 'target', '__index_level_0__'])
test_dataset = test_dataset.remove_columns(['source', 'target', '__index_level_0__'])

# %%
import torch
torch.cuda.empty_cache()

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="./m2m_smugri_finetuned",
    evaluation_strategy="no", 
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    gradient_accumulation_steps=4, 
    weight_decay=0.01,
    save_total_limit=5, 
    save_strategy="no", 
    num_train_epochs=3,
    predict_with_generate=True,
    logging_dir="./logs",
    report_to="none", 
    fp16=True, 
    load_best_model_at_end=False,  
)

def compute_metrics(eval_preds):
    preds, labels = eval_preds
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    decoded_preds = [pred.strip() for pred in decoded_preds]
    decoded_labels = [label.strip() for label in decoded_labels]

    bleu = sacrebleu.corpus_bleu(decoded_preds, [decoded_labels])
    chrf = sacrebleu.corpus_chrf(decoded_preds, [decoded_labels])

    return {"bleu": bleu.score, "chrf": chrf.score}

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='12171' max='12171' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12171/12171 4:20:30, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.815200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.605300</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.520200</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.483900</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.439800</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.421800</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.409100</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.400500</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.365800</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.359900</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.343800</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.341600</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.340300</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.330000</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.327900</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.327700</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.310800</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.299200</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.298100</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.296500</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.296600</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.294200</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.293600</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.295200</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=12171, training_loss=0.3826604242460385, metrics={'train_runtime': 15632.2783, 'train_samples_per_second': 12.458, 'train_steps_per_second': 0.779, 'total_flos': 5.27516602246103e+16, 'train_loss': 0.3826604242460385, 'epoch': 2.999815145726785})

# %%
model.save_pretrained("./m2m_smugri_finetuned_checkpoint")
tokenizer.save_pretrained("./m2m_smugri_finetuned_checkpoint")
# Out:
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 200, 'early_stopping': True, 'num_beams': 5}

# %%
model.eval()
# Out:
# M2M100ForConditionalGeneration(
#   (model): M2M100Model(
#     (shared): M2M100ScaledWordEmbedding(128109, 1024, padding_idx=1)
#     (encoder): M2M100Encoder(
#       (embed_tokens): M2M100ScaledWordEmbedding(128109, 1024, padding_idx=1)
#       (embed_positions): M2M100SinusoidalPositionalEmbedding()
#       (layers): ModuleList(
#         (0-11): 12 x M2M100EncoderLayer(
#           (self_attn): M2M100Attention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): ReLU()
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): M2M100Decoder(
#       (embed_tokens): M2M100ScaledWordEmbedding(128109, 1024, padding_idx=1)
#       (embed_positions): M2M100SinusoidalPositionalEmbedding()
#       (layers): ModuleList(
#         (0-11): 12 x M2M100DecoderLayer(
#           (self_attn): M2M100Attention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (activation_fn): ReLU()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): M2M100Attention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=1024, out_features=128109, bias=False)
# )

# %%
import random 
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

random.seed(42) 
random_indices = random.sample(range(len(test_dataset)), 1000)
random_test_samples = [test_dataset[i] for i in random_indices]

def generate_translation(sample):
    input_ids = torch.tensor(sample['input_ids']).unsqueeze(0).to(device)  # Конвертируем список в тензор
    with torch.no_grad():
        generated_ids = model.generate(input_ids, max_length=200, num_beams=5, early_stopping=True)
    return tokenizer.decode(generated_ids[0], skip_special_tokens=True)

original_texts = []
correct_translations = []
model_translations = []

for sample in tqdm(random_test_samples):
    input_text = tokenizer.decode(sample['input_ids'], skip_special_tokens=True)
    correct_translation = tokenizer.decode(sample['labels'], skip_special_tokens=True)
    model_translation = generate_translation(sample)

    original_texts.append(input_text)
    correct_translations.append(correct_translation)
    model_translations.append(model_translation)
    
df_results = pd.DataFrame({
    "Original Text": original_texts,
    "Correct Translation": correct_translations,
    "Model Translation": model_translations
})
# Out:
# 100%|██████████| 1000/1000 [13:12<00:00,  1.26it/s]

# %%
df_results.head()
# Out:
#                                        Original Text  \
# 0                      __en__ Отсюда подальше уходи.
# 1  __en__ Этот дом с осени работает, и дети сейча...
# 2  __en__ Его во время войны снайпером звали. И с...
# 3  __en__ Такое собрание в нашем округе впервые п...
# 4       __en__ И отправился мальчик с ними в дорогу.
#
#                                  Correct Translation  \
# 0                           __en__ Тыгыл э̄ла минэн.
# 1  __en__ Ты кол таквсы пораныл рпиты, ос ня̄врам...
# 2  __en__ Хо̄нт порат тав снайперыг ла̄ввес... Нё...
# 3  __en__ Тамле сапра̄ни ты та̄л ма̄н округувт о̄...
# 4           __en__ Пыгрись ос та̄н ётаныл минмыгтас.
#
#                                    Model Translation
# 0                         __en__ Тыгыл э̄лаль минэн.
# 1  __en__ Ты кол таквсы па̄сныл рпиты, ос ня̄врам...
# 2  __en__ Тав хо̄нтлын порат снайперыг ла̄ввес. Н...
# 3  __en__ Тамле сапра̄ни ма̄н округувт о̄выл щёс ...
# 4           __en__ Пыгрись та̄н ётаныл лё̄хын минас.

# %%
df_results.loc[:, 'Original Text'] = df_results['Original Text'].str.replace('__en__', '')
df_results.loc[:, 'Correct Translation'] = df_results['Correct Translation'].str.replace('__en__', '')
df_results.loc[:, 'Model Translation'] = df_results['Model Translation'].str.replace('__en__', '')
    
bleu_score = sacrebleu.corpus_bleu(df_results['Model Translation'].tolist(), 
                                   [df_results['Correct Translation'].tolist()]).score
chrf_score = sacrebleu.corpus_chrf(df_results['Model Translation'].tolist(), 
                                   [df_results['Correct Translation'].tolist()]).score

print(f"BLEU Score: {bleu_score}")
print(f"ChrF Score: {chrf_score}")

df_results.head(50)
# Out:
# BLEU Score: 19.11751671599327
# ChrF Score: 50.052403383616465
#                                         Original Text  \
# 0                              Отсюда подальше уходи.
# 1    Этот дом с осени работает, и дети сейчас так ...
# 2    Его во время войны снайпером звали. И соболь ...
# 3    Такое собрание в нашем округе впервые подгото...
# 4               И отправился мальчик с ними в дорогу.
# 5    Первую неделю дети учились готовить националь...
# 6    Два моих сына оба в армии служили, в городе М...
# 7          Я девушка манси, меня зовут Полина Албина.
# 8                                 К дому так подошли.
# 9                   Они говорили, что готовы умереть.
# 10              Вновь заехал в тот чум, вошёл внутрь.
# 11                                     Ко дню победы.
# 12   С ними в округе и других местах ездили с конц...
# 13   Детям в садике таким подарком очень обрадовал...
# 14   Как они свою культуру дальше продолжат, на св...
# 15     И больше никого и ничего на этом поле не было.
# 16   В апреле самка приносит двух или трёх детёнышей.
# 17   Если люлька обветшает, её уносят в лес и подв...
# 18                         Пусть я бы для тебя сделал
# 19   Девшек всех вытянули, а он только появляться ...
# 20      Ханты-Мансийск - главный город нашего округа.
# 21   В округе создаются общины для развития частно...
# 22   В книге под названием «Детство, опалённое вой...
# 23                   Пришел к тому озеру, остановился
# 24         Поэтому не одной косточки не давай собаке.
# 25   До двадцати пяти лет я десяток слов только знал.
# 26   Конечно же, перед нами собаки к хозяйке своей...
# 27              С нами он по-мансийски разговаривает.
# 28            Когда потеплеет, утиные стаи вернуться.
# 29                                   - Ладно, возьму.
# 30   Морж – это гигантское морское животное, он им...
# 31   С женщиной, с полной гружёной нартой и с женщ...
# 32   "Если не подходящий человек пришёл, его мехов...
# 33   Вот подняли, а под камнем яма – полна золотом...
# 34   Пригнулся он, а из-за ракитовых кустов летят ...
# 35   Осерчал конь пуще прежнего: прыгнул - и доста...
# 36   Дал ей огниво, кремешок, трут и мешочек круп ...
# 37   Самый первый форум для молодёжи был в поселке...
# 38           Тётушка только сейчас стала хорошо жить.
# 39   Смена под названием «Языковая» работает с 10 ...
# 40   А после этого речь зашла о заработной плате д...
# 41                      Он пополам перегрыз шею оленю
# 42   Заинька, надень кисы, вот так и этак кисы надень
# 43   Когда замуж вышла, он тоже оленеводом был, де...
# 44   В других секциях собирались учёные социологи ...
# 45                         Тот, который на Обь ездит.
# 46   А отчего же тогда ты, лось, на свободе? — не ...
# 47      Железным большим каким-то предметом обделали.
# 48                                      Сюда подошёл.
# 49            Бурки ещё не дошиты, носовые части шью.
#
#                                   Correct Translation  \
# 0                                   Тыгыл э̄ла минэн.
# 1    Ты кол таквсы пораныл рпиты, ос ня̄врамыт ань...
# 2    Хо̄нт порат тав снайперыг ла̄ввес... Нёхыс ат...
# 3    Тамле сапра̄ни ты та̄л ма̄н округувт о̄выл щё...
# 4                   Пыгрись ос та̄н ётаныл минмыгтас.
# 5    О̄выл са̄тыт а̄гирищит-пыгрищит тэ̄нут ва̄рук...
# 6    Пыгагум сас армиян ялсы̄г, Муравленко ст хани...
# 7               Ам ма̄ньщи а̄ги, намум Полина Албина.
# 8                                    Колн ты ёхтысыг.
# 9               Ла̄всасыт, эрттум холукв ка̄саще̄гыт.
# 10              Та ёхталам ё̄рнколн-ё̄хты, юв ся̄лты.
# 11                              Победа хо̄тал кастыл.
# 12   Та̄н ётыл округ янытыл ос мо̄т хо̄н ма̄н конц...
# 13   Садикн о̄лнэ ня̄врамыт тамле э̄рнэ ёнгынутытн...
# 14   Хумус та̄н культураныл э̄лаль тотыяныл, та̄нт...
# 15   Во̄ссыг нэ̄мхо̄тьют и нэ̄матыр ти ха̄рамат ат...
# 16   Яныгпо̄ль э̄тпос нэ̄ йхул тотункви китыг а̄ма...
# 17          Пēс а̄па во̄рн тотаве, ха̄льйвн тагатаве.
# 18                                Наын вос ва̄рнувлум
# 19   А̄гит пуссын но̄х-хасумтавēсыт, ос такви но̄х...
# 20                Ханты-Мансйск - ты округув яныг сэ.
# 21            Округт са̄лы янмалтан общинат ва̄рēгыт.
# 22   Мо̄т «Детство, опалённое войной» нампа нэ̄пак...
# 23                        Ёхтыс та тур ватан ёл люлис
# 24       Ти магы̄с сяр и а̄ква лв, кутювы̄н ул маген.
# 25   Ва̄т нупыл ат та̄лум мус ам ловмантем ла̄ты т...
# 26   Атхунь, ма̄н э̄лы-па̄лувт ктьванув на̄яныл па...
# 27              Ма̄н ётув тав ма̄ньщи ла̄тыл потырты.
# 28   Ма̄лтыпыг ēмтнэ юи-па̄лт, ва̄с анят ювле ё̄хт...
# 29                                 -Ка̄сащим,вы̄йлум.
# 30   Ся̄рысь й – тыи сака яныг й, тав тит яныг пук...
# 31                           Нэ̄ та̄глуп та̄глы суныл
# 32   "Ат ровнэ э̄лумхо̄лас ке ёхтыс, тай пуны па̄с...
# 33   А̄хвтас нох-а̄лмыстэ̄н, а̄хвтас ёлы-па̄лт во̄...
# 34                     Хо̄т ро̄щьт та̄палт па̄тамтас.
# 35   Хо̄т - ка̄нтма̄явес лув са̄ртын иис порат: по...
# 36   Мис та̄вен щēранка, но̄х - пēламтан а̄хтас, т...
# 37   Ма̄ньлат ма̄хум щар о̄выл форуманыл Белоярски...
# 38           Āкв э̄кватэ ущта ёмщаквег о̄лукве патыс.
# 39   – «Языковая» нампа смена о̄йттур э̄тпос 10 хо...
# 40   Ты юи-па̄лт ос депутатыт сэ̄лнэ олнаныл урыл ...
# 41                       Тав супыг салы сыплув пурме.
# 42   Со̄выркве, ва̄й масэн, ты щир, та щир ва̄й масэн
# 43   Хунь хум ва̄рсум, тав о̄с са̄лы хум, ня̄врама...
# 44   Мо̄т секцият социолог ос экономист учёныит ак...
# 45                           Ань А̄сын ялнэ утэ урыл.
# 46   – Ос на манрыг ат тйтвесын, Янгуй? – Тасман о...
# 47                   Кēр о̄лнэ яныг тэ̄рмыл ва̄равем.
# 48                                         Тыг ёхтыс.
# 49               Пркай и ат а̄стэ̄й, а̄мнаēн ю̄нтъяюм
#
#                                     Model Translation
# 0                                 Тыгыл э̄лаль минэн.
# 1    Ты кол таквсы па̄сныл рпиты, ос ня̄врамыт ань...
# 2    Тав хо̄нтлын порат снайперыг ла̄ввес. Нёхс ат...
# 3    Тамле сапра̄ни ма̄н округувт о̄выл щёс щё̄пит...
# 4                   Пыгрись та̄н ётаныл лё̄хын минас.
# 5    О̄выл са̄т ня̄врамыт лима̄ мир тэ̄нут па̄йтук...
# 6    Кит пыгагум сас армият лусытасыт, Муравленко ...
# 7            Ам ма̄ньщи а̄ги, ам намум Полина Албина.
# 8                                  Колн тох ёхтысы̄г.
# 9                  Та̄н ла̄всыт, та̄н а̄тимыг ēмтсыт.
# 10                 О̄с та ё̄рнколн сялтыс, юв сялтыс.
# 11                          Но̄х патум хо̄тал кастыл.
# 12   Та̄н ётаныл округувт ос мо̄т ма̄т концертный ...
# 13    Ня̄врамыт садикыт тамле мйлупсал сака ща̄гтсыт.
# 14   Хумус та̄н культураныл э̄лаль э̄лаль ва̄ре̄гы...
# 15   Ос воссыг нэ̄мхотьют ос нэ̄матыр ты ма̄т а̄ти...
# 16   Яныгпо̄ль э̄тпост хум кит манос хрум ня̄врам ...
# 17   А̄па ке во̄таве, таве во̄рн тотыглаве ос ха̄л...
# 18                              Ам наын вос ва̄рнувум
# 19   А̄гирищит пуссын кон-ква̄лве̄сыт, ос тав туп ...
# 20              Ханты-Мансийск – ма̄н округув яныг с.
# 21        Округувт са̄лы рнэ ма̄гыс общинат ва̄равет.
# 22   «Детство, опалённое войной» нампа нэ̄пакт Оль...
# 23                       Та тр палт ёхтыс, ёл-по̄йтыс
# 24                 Таима̄гыс акв лув ул мирен ктювын.
# 25           Хус ат та̄л мус ам лов ла̄ты ущ ва̄слум.
# 26   Ва̄им, ма̄н э̄лы-па̄лувт а̄мпыт ксяяныл палт ...
# 27              Ма̄н ётув тав ма̄ньщи ла̄тыл потырты.
# 28              Хунь исылтаве, ва̄с поталыт ёхтэ̄гыт.
# 29                                    - Я̄тил, выгум.
# 30   Морж – ты яныг ща̄рыщ й, тав кит яныг па̄к, я...
# 31                          Та̄глы суны нэ̄ ос нэ̄ ёт
# 32   "Э̄лумхо̄лас ат ке ёхтыс, тав о̄лнэ ка̄т о̄лн...
# 33   А̄хвтас а̄хвтас ёлы-па̄лт та̄глы со̄рни та̄гл...
# 34   Тав ёл-порыгмас, ос ракитовый нирщахыл ма̄ сы...
# 35   О̄влэ̄т лув псхатас: порыгмас, и снас мус ёхтыс.
# 36   Тавēн на̄йив, та̄рвит, сяхыл ос хрыг яныг мис...
# 37   Щар о̄выл форум ма̄ньлат ма̄хум ма̄гыс Белояр...
# 38                А̄кве ань туп ёмщакв о̄лукве патыс.
# 39   «Языковая» нампа смена лпта э̄тпос 10 хо̄талн...
# 40   Та юи-па̄лт депутатыт рпата олныт урыл потыртас.
# 41               Тав са̄лы сыплуве киттыг са̄грапастэ
# 42     Со̄выркве, ва̄с масэ̄лн, тыщир ос ва̄с масэ̄лн
# 43   Хунь хум ва̄рсум, тав о̄с са̄лы рнэ хо̄тпаг о...
# 44   Мо̄т секцият учёный хо̄тпат социологыт ос эко...
# 45                             А̄с нупыл ялантан хум.
# 46   Ос манрыг то̄нт на, со̄рп, рхатаслын? – Тасма...
# 47                     Кēр яныг матыр пормас ва̄рвес.
# 48                                         Тыг ёхтыс.
# 49         Пркат и ат па̄хвтасыт, нёлэ̄ныл ю̄нтэ̄гум.

# %%
import shutil
shutil.make_archive("m2m_smugric_finetuned", 'zip', "/kaggle/working/m2m_smugri_finetuned_checkpoint")
# Out:
# '/kaggle/working/m2m_smugric_finetuned.zip'

# %%
from IPython.display import FileLink

FileLink('m2m_smugric_finetuned.zip')
# Out:
# /kaggle/working/m2m_smugric_finetuned.zip

# %%
# Out:
# 1

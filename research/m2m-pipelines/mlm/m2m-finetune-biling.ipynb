# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.1 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from sacrebleu) (2024.5.15)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.10/site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from sacrebleu) (1.26.4)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from sacrebleu) (5.3.0)
# Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 7.0 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Installing collected packages: portalocker, sacrebleu
# Successfully installed portalocker-2.10.1 sacrebleu-2.4.3

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer, Seq2SeqTrainer, Seq2SeqTrainingArguments
from datasets import Dataset
import sacrebleu

# %%
# %%time
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer

model_name = "/kaggle/input/m2m-bilingual"
model = M2M100ForConditionalGeneration.from_pretrained(model_name)
tokenizer = M2M100Tokenizer.from_pretrained(model_name)
# Out:
# CPU times: user 6.78 s, sys: 1.29 s, total: 8.06 s
# Wall time: 12.1 s

# %%
df = pd.read_csv("/kaggle/input/mansi-russian-parralel-corpus/overall_80K.csv", index_col=0)

# %%
df['to'] = 'mns'

# %%
df_other = df.copy()
df_other['to'] = 'ru'
df_other['source'], df_other['target'] = df_other['target'], df_other['source']

# Concatenate the original df and df_other
df = pd.concat([df, df_other], ignore_index=True)

# %%
train_df, test_val_df = train_test_split(df, test_size=0.2, random_state=42,shuffle=True, stratify=df['to'])
val_df, test_df = train_test_split(test_val_df, test_size=0.5, random_state=42, shuffle=True, stratify=test_val_df['to'])

# %%
# %%time
train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)
test_dataset = Dataset.from_pandas(test_df)
# Out:
# CPU times: user 11 ms, sys: 2.87 ms, total: 13.9 ms
# Wall time: 12.7 ms

# %%
tokenizer.add_special_tokens({'additional_special_tokens': ['<mns_MNS>']})
model.resize_token_embeddings(len(tokenizer))
# Out:
# M2M100ScaledWordEmbedding(128105, 1024, padding_idx=1)

# %%
def preprocess_function(examples):
    inputs = tokenizer(examples['source'], truncation=True, padding='max_length', max_length=128)
    targets = tokenizer(examples['target'], truncation=True, padding='max_length', max_length=128)
    inputs['labels'] = targets['input_ids']
    return inputs

# %%
# %%time
train_dataset = train_dataset.map(preprocess_function, batched=True)
val_dataset = val_dataset.map(preprocess_function, batched=True)
test_dataset = test_dataset.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# CPU times: user 3.4 s, sys: 4.91 ms, total: 3.4 s
# Wall time: 3.4 s

# %%
train_dataset = train_dataset.remove_columns(['source', 'target', '__index_level_0__', 'to'])
val_dataset = val_dataset.remove_columns(['source', 'target', '__index_level_0__', 'to'])
test_dataset = test_dataset.remove_columns(['source', 'target', '__index_level_0__', 'to'])

# %%
import torch
torch.cuda.empty_cache()

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="./mansi_finetuned_biling",
    eval_strategy="no",  # отключаем валидацию 
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    gradient_accumulation_steps=4, 
    weight_decay=0.01,
    save_total_limit=5, 
    save_strategy="epoch",  # сохраняем токо после каждой эпохи
    num_train_epochs=1,
    predict_with_generate=True,
    logging_dir="./logs",
    report_to="none", 
    fp16=True, 
    load_best_model_at_end=False,  # вырубаем загрузку лучшей модели в конце
)

def compute_metrics(eval_preds):
    preds, labels = eval_preds
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # убираем токены pad
    decoded_preds = [pred.strip() for pred in decoded_preds]
    decoded_labels = [label.strip() for label in decoded_labels]

    # вычисление метрик
    bleu = sacrebleu.corpus_bleu(decoded_preds, [decoded_labels])
    chrf = sacrebleu.corpus_chrf(decoded_preds, [decoded_labels])

    return {"bleu": bleu.score, "chrf": chrf.score}

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# Тренировка модели
trainer.train()
# Out:
# /opt/conda/lib/python3.10/site-packages/accelerate/accelerator.py:488: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
#     <div>
#
#       <progress value='8114' max='8114' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8114/8114 2:54:45, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>2.130700</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.500800</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.458200</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.428900</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.403100</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.386000</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.378600</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.368300</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.357700</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.352000</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.348400</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.344400</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.339200</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.334600</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.329500</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.332900</td>
#     </tr>
#   </tbody>
# </table><p>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 200, 'early_stopping': True, 'num_beams': 5}
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 200, 'early_stopping': True, 'num_beams': 5}
# TrainOutput(global_step=8114, training_loss=0.4849136508624778, metrics={'train_runtime': 10487.7495, 'train_samples_per_second': 12.379, 'train_steps_per_second': 0.774, 'total_flos': 3.5167773483073536e+16, 'train_loss': 0.4849136508624778, 'epoch': 0.9999075757108968})

# %%
import shutil
from IPython.display import FileLink

shutil.make_archive("m2m_biling_finetune", 'zip', "/kaggle/working/mansi_finetuned_biling/")
# Out:
# '/kaggle/working/m2m_biling_finetune.zip'

# %%
FileLink('m2m_biling_finetune.zip')
# Out:
# /kaggle/working/m2m_biling_finetune.zip

# %%
# %%time
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

random.seed(42) 
# random_indices = random.sample(range(len(test_dataset)), 1000)
random_test_samples = test_dataset

def generate_translation(sample):
    input_ids = torch.tensor(sample['input_ids']).unsqueeze(0).to(device)  # Конвертируем список в тензор
    with torch.no_grad():
        generated_ids = model.generate(input_ids, max_length=200, num_beams=5, early_stopping=True)
    return tokenizer.decode(generated_ids[0], skip_special_tokens=True)

original_texts = []
correct_translations = []
model_translations = []

for sample in tqdm(random_test_samples):
    input_text = tokenizer.decode(sample['input_ids'], skip_special_tokens=True)
    correct_translation = tokenizer.decode(sample['labels'], skip_special_tokens=True)
    model_translation = generate_translation(sample)

    original_texts.append(input_text)
    correct_translations.append(correct_translation)
    model_translations.append(model_translation)
    
df_results = pd.DataFrame({
    "Original Text": original_texts,
    "Correct Translation": correct_translations,
    "Model Translation": model_translations
})
# Out:
# 100%|██████████| 1/1 [00:17<00:00, 17.37s/it]
# CPU times: user 9.32 s, sys: 1.08 s, total: 10.4 s
# Wall time: 17.4 s

# %%
df_results.loc[:, 'Original Text'] = df_results['Original Text'].str.replace('__en__', '')
df_results.loc[:, 'Correct Translation'] = df_results['Correct Translation'].str.replace('__en__', '')
df_results.loc[:, 'Model Translation'] = df_results['Model Translation'].str.replace('__en__', '')
    
bleu_score = sacrebleu.corpus_bleu(df_results['Model Translation'].tolist(), 
                                   [df_results['Correct Translation'].tolist()]).score
chrf_score = sacrebleu.corpus_chrf(df_results['Model Translation'].tolist(), 
                                   [df_results['Correct Translation'].tolist()]).score

print(f"BLEU Score: {bleu_score}")
print(f"ChrF Score: {chrf_score}")

df_results.head(50)
# Out:
# BLEU Score: 17.566674560348577
# ChrF Score: 45.26100148066748
#                                         Original Text  \
# 0    Йпыг-пы̄грись нампа о̄йка ань та̄н ли па̄ланы...
# 1                                           О̄с айыс.
# 2    Хунь Иаков хлыстэ, Иосиф лылы, сыме хот-ся̄гтыс.
# 3    Ос илттыг арēнан са̄в акроба̄т та ха̄йтлыгтас...
# 4    Фашистыт 872 хо̄тал Ленинградын нэ̄мхотьют ат...
# 5                                Этот старик рыбачит.
# 6    Та̄л сыс ма̄хманэ ёт маныр ва̄рсыт, тав ань п...
# 7                           Нор аняв акваг та яныгми.
# 8    Э̄ква-пыгрись Па̄йпы э̄ква ня̄врамыг ма̄гыс м...
# 9    Спросите вот моего сынишку, какого мы раз пой...
# 10   И в глухие полярные ночи долго не потухал ого...
# 11   А Берта дуру по- русски уже хорошо понимает, ...
# 12              439.Атэ ма, атэ вит манавн ат нангки.
# 13   Тогда начальники администрации округа сказали...
# 14   Затем Валеру призвали в армию, служил в Герма...
# 15     Ма̄н ёхтынэ̄в кастыл мис нуен, тэ̄нут па̄йтэн.
# 16   В этих краях. с давних времён ещё и народ хан...
# 17                                  Но̄х хо̄тылтэ̄лн!
# 18   Тэ̄лы па̄выл вēрыстат о̄лыс, тэ̄лы лё̄х кит п...
# 19   Ускорив шаг, я подошёл к сыну и взял его за р...
# 20   Ханищтап ос ма̄ньлат ма̄хум Департаментыт кща...
# 21   Та̄н нё̄тнэ сахи, мольща ос ла̄гыл ре̄гы масн...
# 22   Еремей Айпин про эти дела так сказал:" Семьи ...
# 23       Ня̄врамыт пе̄с йис ва̄рмалитыл пмщалахтэ̄гыт
# 24   Ты та̄лт Белоярский районт о̄лнэ "Югра лылыēп...
# 25                              Нял пальхэ исылтас тэ
# 26   Сказала: "Начнется долгая человеческая жизнь,...
# 27                 В дремучие леса на его семь углов.
# 28   Библиотекан минасум, Михаил Шолохов хансум «П...
# 29    Хунь Выгыр кēнткве ёхтыс, тав ос а̄ви туясастэ.
# 30   Она фотографировала на фотоаппарат и умела пе...
# 31   Па̄кв паттукве, ла̄хс атукве ос пил ва̄тукве ...
# 32                         Лебедь то куда-то исчезла.
# 33         Взрослых людей слова всегда слушать нужно.
# 34                              Он поднялся на берег.
# 35                                   Са̄лы сун харти.
# 36                 Больных женщин, если есть, исцели.
# 37   Валентина Шадрина в Сургутском районе работае...
# 38                Для подушечки новую наволочку сшей’
# 39   Тав такос воритотыс, таитэ̄н тай кон-пувтмала...
# 40    - Врёшь, врёшь! - Выскочил из-за телеги Санька.
# 41   Она так бледна, что густые веснушки на её лиц...
# 42   Сталин работал, склонясь над письменным столи...
# 43           Росомаха охотится как днём, так и ночью.
# 44   Хум ёл-ойвес, а Ванька лув суп ква̄лыг вистэ ...
# 45                               А̄ви кол коныпа̄лна.
# 46   103.Он аккуратно принимает от меня все прибор...
# 47   Он говорит:- "В этом кедровом бору ведь медве...
# 48   То̄ва ле̄ккарыт Тюмень с па̄сныл рпитакве тув...
# 49   Аман хоса ё̄ми, аман вāти ё̄ми, аквматэ̄рт су...
#
#                                   Correct Translation  \
# 0    Мужчина по имени Йипыг-пыгрись жил севернее и...
# 1                                       Опять выпила.
# 2    Когда Иаков услышал, что Иосиф жив, то возлик...
# 3          И на арену выбежало множество акробатов...
# 4    Фашисты 872 дня в Лениград никого впускали, г...
# 5                           Ты матум о̄йка хл алыщлы.
# 6    В течение года что они с сотрудниками сделали...
# 7                          Гора из бревен всё растёт.
# 8    Что предложил Эква пыгрись смастерить детям ж...
# 9    Китылэ̄н ам пы̄гум, ма̄нхурп ман акв сёс пвы̄...
# 10   Ситам ли э̄тт хл алисьлан хум ко̄лрисьт найкв...
# 11   Берта о̄тсам рсь ла̄тыл ос ё̄мсякв то̄ргамти,...
# 12                         439.Земли и воды не видно.
# 13   То̄нт округ миркол кщаит щар ёмас нэ̄пакыт ха...
# 14   Тувыл Валера армиян вуйвес ос Германият лусытас.
# 15      К нашему приходу корову заколи, кушать свари.
# 16   Та ма̄т пēс йис та̄гыл ма̄ньщи ос ханты ма̄ху...
# 17                                       Вверх озари!
# 18   Зимние юрты располагались недалеко от летних,...
# 19   Моля̄хнув усы̄л, ам ляпан-ё̄хтысум пы̄гум пох...
# 20   Директор Департамента образования и молодёжно...
# 21   Они красивую шубу, малицу и для ног теплую об...
# 22   Еремей Айпин ты тэ̄- лат урыл тох ла̄выс: «Ма...
# 23                  Дети интересуются старыми делами.
# 24   В этом году руководителем организации "Спасен...
# 25                     Наконечник стрелы накаливается
# 26   Лави: "Э̄лмхо̄лас йисы то̄рм, э̄лмхо̄лас ноты...
# 27                             Сэ̄р во̄р са̄т са̄мна.
# 28   Пришла в библиотеку, выбрала книгу Михаила Шо...
# 29   Когда Красная шапочка пришла, она тоже толкну...
# 30   Ос фотоаппаратын хурит по̄слыс, хурит ва̄рукв...
# 31   Шишки шибать, грибы и ягоды собирать мы недал...
# 32                         Хота тай хотталь та минас.
# 33            Яныг хо̄тпат ла̄тын аквай хнтлукв э̄ри.
# 34              Тав я̄ ватан но̄х - ха̄нха̄нта̄нквум.
# 35                                 Олень везёт нарту.
# 36               А̄гмы нэ̄ ке о̄лы; но̄х пусмалтэ̄лн.
# 37   Валентина Шадрина Сургутский районный методич...
# 38       Осмахрыгсов лильпи осмахрыг то̄рыл ю̄нтэ̄лын
# 39   Он не слушается, тот его на улицу вытолкает, ...
# 40   - ркегын, ркегын! - ко̄н- по̄рымас сн са̄йныл...
# 41   Тав такемта вильтэ нуйхатам, вильтэ̄т сэ̄мыл ...
# 42      Сталин, хаснэ пасанэ нуми-палт хтим, рупитас.
# 43       Тулмах во̄раянкви хо̄мыс хо̄тыл, та̄сирь ти.
# 44   Мужик заснул в телеге, а Ванька взял вожжи и ...
# 45                           За двери дома с дверями.
# 46   103.Тав приборыт ос книгат анумныл ургалим ва...
# 47   Тав ла̄ви: – Алам ты льпа урт во̄рто̄лнут ё̄м...
# 48   Некоторые врачи приезжали туда работать из го...
# 49   Долго ли идёт, коротко ли идёт, в одно время ...
#
#                                     Model Translation
# 0    Мужчина по имени Ипыг-пыгрись сейчас на их бе...
# 1                                       Опять поймал.
# 2    Когда Иаков услышал, что Иосиф жив, сердце ис...
# 3              И вдруг в арню много сразу побежало...
# 4    Фашисты 872 дня в Ленинград никто не пускали,...
# 5                           Ты матум о̄йка хл алыщлы.
# 6    За год с людьми что делали, она сейчас разгов...
# 7                  Наше горное чаше постоянно растёт.
# 8    Эква-пыгрись Пайпы женщина за детей что делат...
# 9    Ам пыгрищум ты китыглэ̄н, манхурип порат ма̄н...
# 10   Ос сакы полярный э̄т хоса ат хл алыщлан хл ал...
# 11   Ос Берта рущ ла̄тыл а̄мпыт ёмщакв торгамты, о...
# 12                    439.Не видно ни земли, ни воды.
# 13   То̄нт округув мирколт кщаит нэ̄пакыл мйлупсал...
# 14   Тувыл Валера армиян во̄ввес, Германия ма̄т лу...
# 15            Когда мы приедем, коров вари, еду вари.
# 16           Ты ма̄т пēс порат ханты ма̄хум о̄лэ̄гыт.
# 17                                            Встань!
# 18   Зимой деревня была на верховьях, на зимней до...
# 19   Молях ё̄мсум, ам пыгум палт ё̄мсум ос ка̄тэ̄н...
# 20   Директор Департамента учебы и молодежи Антони...
# 21   Они имеют красивую шубу, мельчугую и ножную о...
# 22   Еремей Айпин ты тэ̄ла урыл тох ла̄выс: «Ма̄нь...
# 23              Дети интересуются старыми традициями.
# 24   В этом году в Белоярском районе в организации...
# 25                            Огонь с стрелой вытащил
# 26   Ла̄выс: "Хо̄тпа хоса о̄лупса о̄вылтахтэ̄гыт, ...
# 27                              Пēс во̄р са̄т а̄квал.
# 28   Поехала в библиотеку, взяла книгу "Поднятая ц...
# 29   Когда пришла Красная шапочка, она тоже закрыл...
# 30   Тав фотоаппарат нупыл по̄слысанэ ос хурит пе̄...
# 31   Кушать шишки, собирать грибы и собирать ягоды...
# 32                          Лэ̄ын хотталь та нэ̄глыс.
# 33            Яныг хо̄тпат ла̄ты акваг хнтлукве э̄ри.
# 34                              Тав па̄г но̄х-ха̄хыс.
# 35                              Оленей в шкуру тянет.
# 36                    А̄гмы нэ̄ ке о̄лы, пусмалтавес.
# 37   Валентина Шадрина Сургутский район методическ...
# 38                      Нёхыс ма̄гыс йильпи па̄хвтакв
# 39   Он так молчал, что их вытащили на улицу, он т...
# 40   - Вортэ̄гын, вортэ̄гын! - Санька э̄лы-па̄лт н...
# 41   Тав тох сэ̄кв, то̄влы тяг тав нупыл на̄ки и л...
# 42          Сталин рпитас, нэ̄пак пасан нупыл нэ̄глы.
# 43                   А̄мпыт хо̄тыл, э̄тил во̄рае̄гыт.
# 44   Мужчина спустился, а Ванка взял коня в платье...
# 45                               Над домом с дверями.
# 46   103.Тав а̄нумн нэ̄пакыт ос нэ̄пакыт пуссын ак...
# 47   Тав ла̄ви:- "Ты льпа во̄рто̄лнут во̄рто̄лнут ...
# 48   Некоторые врачи с города Тюмени туда работать...
# 49   Долго ли идёт, коротко ли идёт, вдруг смотрит...
